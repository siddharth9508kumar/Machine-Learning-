# %% [markdown]
# # LUNG CANCER : Risk Factor Analysis' or 'Exploratory Data Analysis of Lung Cancer dataset

# %%
import pandas as pd


df=pd.read_csv('lung_cancer_examples.csv')
df.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
missing_count=df.isnull().sum()
print("missing count:",missing_count)
missing_percentage=(missing_count/len(df))*100
print("missing percentage:",missing_percentage)
# Out:
# missing count: Name       0
# Surname    0
# Age        0
# Smokes     0
# AreaQ      0
# Alkhol     0
# Result     0
# dtype: int64
# missing percentage: Name       0.0
# Surname    0.0
# Age        0.0
# Smokes     0.0
# AreaQ      0.0
# Alkhol     0.0
# Result     0.0
# dtype: float64

# %%
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
import matplotlib.pyplot as plt
df['Result'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.xlabel('lung_cancer')
plt.ylabel('count')
plt.title('lung_cancer distribution')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
col='Age'
plt.figure(figsize=(10,6))
plt.hist(df[col].dropna(),bins=20,color='skyblue',edgecolor='black')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=df,x='Age',y='Result')
plt.title("Boxplot of Age vs Result")
plt.xlabel("Age")
plt.ylabel("Result")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
num_features = df.select_dtypes(include=[np.number]).columns.tolist()
print(f"Numerical Features: {num_features}")
corr=df[num_features].corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Numerical Features: ['Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result']
